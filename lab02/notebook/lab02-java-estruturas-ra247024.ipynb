// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
int s = 200, n =5, i;
double Patual, j = 1;
Patual = s;

for(i = 0; i < n; i++){
    System.out.print(Patual+" ");
    Patual = Patual * (1 + j / 100);
}
// Out:
// 200.0 202.0 204.02 206.0602 208.120802
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Emprestimo{
    static void proximaParcela(int s, int n, double j){
        double Patual;
        Patual = s;
        
        for(int i = 0; i < n; i++){
            System.out.print(Patual+" ");
            Patual = Patual * (1 + j / 100);
        }  
    }  
}
// Out:
// com.twosigma.beaker.javash.bkr740800a8.Emprestimo

// %%
int s, n, i;
s = 200; n =5; 
double Patual, j;
j = 1;
Patual = s;

Emprestimo.proximaParcela(s,n,j);
// Out:
// 200.0 202.0 204.02 206.0602 208.120802
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
public class Binario{
    static String converteDec_Bin(int n){
        String montagem = "", bin = "";
        int resto;

        while(n != 0){
            resto = n % 2;
            if(resto == 1){
                montagem = montagem + "1";
            }
            else{
                montagem = montagem + "0";
            }
            n = n / 2;
        }

        for(int i = montagem.length() - 1; i >= 0; i--){
            bin = bin + montagem.charAt(i);
        }

        return bin;
    }
}
// Out:
// com.twosigma.beaker.javash.bkr740800a8.Binario

// %%
import java.util.Random;

Random rand = new Random();
int numero;

numero = rand.nextInt(9999);

System.out.println("Numero decimal:" + numero);
System.out.println("Numero binario:" + Binario.converteDec_Bin(numero));
// Out:
// Numero decimal:4326
// Numero binario:1000011100110
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class Gene{

    static String constroiRNA(String DNA) {
        String RNA = "";
        int tamanho;
        tamanho = DNA.length(); 

        for(int i = 0; i < tamanho; i++){
            char letra = DNA.charAt(i);
            if(letra == 'A'){
                RNA = RNA + "C";
            }
            else if(letra == 'C'){
                RNA = RNA + "A";
            }
            else if(letra == 'T'){
                RNA = RNA + "G";
            }
            else if(letra == 'G'){
                RNA = RNA + "T";
            }
        }

       return RNA;
    }
}
// Out:
// com.twosigma.beaker.javash.bkr740800a8.Gene

// %%
String DNA, RNA;
DNA = "ACGTGC";

RNA = Gene.constroiRNA(DNA);

System.out.print(RNA);
// Out:
// CATGTA
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;
Random rand = new Random();
int numeros[] = new int[50];
float soma = 0, media;
int cont = 0;
    
for(int i = 0; i < 50; i++){
    numeros[i] = rand.nextInt(12500) + 2500;
    soma = soma + numeros[i];
}

media = soma/50;
for(int i = 0; i < 50; i++){
    if(numeros[i] > media){
        cont++;
        System.out.println("salario acima da média " + cont + ": R$ " + numeros[i] + ",00");
    }
}
System.out.println("Na empresa  " + cont + " funcionarios recebem um salario acima da média.");
// Out:
// salario acima da média 1: R$ 12773,00
// salario acima da média 2: R$ 10892,00
// salario acima da média 3: R$ 11723,00
// salario acima da média 4: R$ 8978,00
// salario acima da média 5: R$ 10790,00
// salario acima da média 6: R$ 11161,00
// salario acima da média 7: R$ 12061,00
// salario acima da média 8: R$ 11556,00
// salario acima da média 9: R$ 9650,00
// salario acima da média 10: R$ 13776,00
// salario acima da média 11: R$ 9056,00
// salario acima da média 12: R$ 8914,00
// salario acima da média 13: R$ 8842,00
// salario acima da média 14: R$ 11309,00
// salario acima da média 15: R$ 9264,00
// salario acima da média 16: R$ 11289,00
// salario acima da média 17: R$ 11812,00
// salario acima da média 18: R$ 9620,00
// salario acima da média 19: R$ 12732,00
// salario acima da média 20: R$ 14333,00
// salario acima da média 21: R$ 9171,00
// salario acima da média 22: R$ 10122,00
// salario acima da média 23: R$ 12129,00
// salario acima da média 24: R$ 14245,00
// salario acima da média 25: R$ 10224,00
// Na empresa  25 funcionarios recebem um salario acima da média.
// null
